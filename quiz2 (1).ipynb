# %%
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import seaborn as sns

# %%
datos = pd.read_csv('historical_data.csv')

# %%
datos
# Out:
#         market_id           created_at actual_delivery_time  store_id  \
# 0             1.0  2015-02-06 22:24:17  2015-02-06 23:27:16      1845
# 1             2.0  2015-02-10 21:49:25  2015-02-10 22:56:29      5477
# 2             3.0  2015-01-22 20:39:28  2015-01-22 21:09:09      5477
# 3             3.0  2015-02-03 21:21:45  2015-02-03 22:13:00      5477
# 4             3.0  2015-02-15 02:40:36  2015-02-15 03:20:26      5477
# ...           ...                  ...                  ...       ...
# 197423        1.0  2015-02-17 00:19:41  2015-02-17 01:24:48      2956
# 197424        1.0  2015-02-13 00:01:59  2015-02-13 00:58:22      2956
# 197425        1.0  2015-01-24 04:46:08  2015-01-24 05:36:16      2956
# 197426        1.0  2015-02-01 18:18:15  2015-02-01 19:23:22      3630
# 197427        1.0  2015-02-08 19:24:33  2015-02-08 20:01:41      3630
#
#        store_primary_category  order_protocol  total_items  subtotal  \
# ...

# %% [markdown]
# pregunta 2

# %%
datos_pizza=datos[datos['store_primary_category']=="pizza"]

# %% [markdown]
# filtramos para que solo aparescan registro de pizza

# %%
datos_pizza
# Out:
#         market_id           created_at actual_delivery_time  store_id  \
# 74            2.0  2015-02-13 03:48:58  2015-02-13 04:26:51      2004
# 249           4.0  2015-01-25 21:27:26  2015-01-25 22:10:14      5081
# 897           3.0  2015-01-25 02:32:10  2015-01-25 03:32:24      6922
# 898           3.0  2015-02-18 03:22:51  2015-02-18 03:49:18      6922
# 899           3.0  2015-01-23 02:05:52  2015-01-23 02:48:35      6922
# ...           ...                  ...                  ...       ...
# 196897        1.0  2015-02-07 03:11:02  2015-02-07 03:44:59      1520
# 197126        2.0  2015-01-23 02:52:55  2015-01-23 03:36:09      1409
# 197222        3.0  2015-01-28 05:13:06  2015-01-28 05:38:48      1340
# 197276        5.0  2015-01-23 04:27:25  2015-01-23 05:09:22      1340
# 197323        4.0  2015-02-13 20:46:24  2015-02-13 21:34:13      6110
#
#        store_primary_category  order_protocol  total_items  subtotal  \
# ...

# %%
datos2=datos_pizza[['store_id' ]]

# %% [markdown]
# tomamos todas als tiendas que venden pizzas

# %%
datos2
# Out:
#         store_id
# 74          2004
# 249         5081
# 897         6922
# 898         6922
# 899         6922
# ...          ...
# 196897      1520
# 197126      1409
# 197222      1340
# 197276      1340
# 197323      6110
#
# [17321 rows x 1 columns]

# %%
datos2=datos2.drop_duplicates()

# %%
datos2
# Out:
#         store_id
# 74          2004
# 249         5081
# 897         6922
# 1129        4616
# 1274        6313
# ...          ...
# 196800      6964
# 196879      1520
# 197126      1409
# 197222      1340
# 197323      6110
#
# [1088 rows x 1 columns]

# %% [markdown]
# al solo tener una colummna eliminas todos las filas repetidas y asi tenemos el cuantas tiendas vende pizzas

# %%
datos2.count()
# Out:
# store_id    1088
# dtype: int64

# %% [markdown]
# contamos cuantas tiendas diferentes venden pizzas en total

# %% [markdown]
# pregunta 3

# %%
datos3=datos[['num_distinct_items','estimated_store_to_consumer_driving_duration']]

# %% [markdown]
# tomamos las colummnas que vamos a analizar

# %%
datos3
# Out:
#         num_distinct_items  estimated_store_to_consumer_driving_duration
# 0                        4                                         861.0
# 1                        1                                         690.0
# 2                        1                                         690.0
# 3                        5                                         289.0
# 4                        3                                         650.0
# ...                    ...                                           ...
# 197423                   3                                         331.0
# 197424                   4                                         915.0
# 197425                   3                                         795.0
# 197426                   1                                         384.0
# 197427                   4                                         134.0
#
# [197428 rows x 2 columns]

# %%
datos3.corr()
# Out:
#                                               num_distinct_items  \
# num_distinct_items                                      1.000000
# estimated_store_to_consumer_driving_duration            0.022693
#
#                                               estimated_store_to_consumer_driving_duration
# num_distinct_items                                                                0.022693
# estimated_store_to_consumer_driving_duration                                      1.000000

# %% [markdown]
# como se puede observar el tiempo de viaje estimado entre la tienda y el consumidor no estan asociados al numero de articulos distintos en la compra, ya que podemosen la matriz de correlacion que la relacion es muy baja entre estas variuables, ya que presenta un valor de 0.022693 un valor muy cercano a  0, y lo ideal es lo mas cercano a 1 o -1.
#
# si hacemos unas colsutas podemos ver que el registro 1 tiene  numero distinto de productos asi como 1 total de productos y tiene una duracion de 690 mientras que otro con un total de 6 productos y 5 son distintos y tiene una duracion de 289, o otro con 3 productos distintos y total 3 y tiene una duracion de 331.

# %% [markdown]
# pregunta 4

# %%
datos4=datos
datos4['delivery_time'] = (pd.to_datetime(datos['actual_delivery_time']) - pd.to_datetime(datos['created_at'])).dt.total_seconds()

# %% [markdown]
# creamos una nueva columna que sera el resultado de los tiempo entre que se pide el pedido y el tiempo que se entrega al cliente

# %%
datos4 = datos4.dropna(axis=0)
datos4
# Out:
#         market_id           created_at actual_delivery_time  store_id  \
# 0             1.0  2015-02-06 22:24:17  2015-02-06 23:27:16      1845
# 1             2.0  2015-02-10 21:49:25  2015-02-10 22:56:29      5477
# 8             2.0  2015-02-16 00:11:35  2015-02-16 00:38:01      5477
# 14            1.0  2015-02-12 03:36:46  2015-02-12 04:14:39      2841
# 15            1.0  2015-01-27 02:12:36  2015-01-27 03:02:24      2841
# ...           ...                  ...                  ...       ...
# 197423        1.0  2015-02-17 00:19:41  2015-02-17 01:24:48      2956
# 197424        1.0  2015-02-13 00:01:59  2015-02-13 00:58:22      2956
# 197425        1.0  2015-01-24 04:46:08  2015-01-24 05:36:16      2956
# 197426        1.0  2015-02-01 18:18:15  2015-02-01 19:23:22      3630
# 197427        1.0  2015-02-08 19:24:33  2015-02-08 20:01:41      3630
#
#        store_primary_category  order_protocol  total_items  subtotal  \
# ...

# %% [markdown]
# eliminamos las fillas null

# %%
datosg1=datos4.groupby('store_primary_category')
datos4['prom']=datosg1['delivery_time'].transform('mean')
datos4.min()
# Out:
# <ipython-input-16-53172b657798>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos4['prom']=datosg1['delivery_time'].transform('mean')
# market_id                                                       1.0
# created_at                                      2015-01-21 15:22:03
# actual_delivery_time                            2015-01-21 16:16:34
# store_id                                                          1
# store_primary_category                                       afghan
# order_protocol                                                  1.0
# total_items                                                       1
# subtotal                                                          0
# ...

# %% [markdown]
# Agrupamos por diferentes tipos de comida para asi sacar el promedio de cuanto se tarda cada comida

# %% [markdown]
# buscamos el valor minimo de de los tiempos '2048'

# %%
datos5=datos4
datos6=datos5

# %%
datos6=datos5.set_index('prom', inplace=True)

# %% [markdown]
# ponemos los tiempos como indices

# %%
datos5.loc[2048]
# Out:
# market_id                                                       4.0
# created_at                                      2015-01-24 00:42:24
# actual_delivery_time                            2015-01-24 01:16:32
# store_id                                                       6165
# store_primary_category                                    chocolate
# order_protocol                                                  1.0
# total_items                                                       1
# subtotal                                                       2650
# num_distinct_items                                                1
# min_item_price                                                 2650
# max_item_price                                                 2650
# total_onshift_dashers                                          52.0
# total_busy_dashers                                             39.0
# total_outstanding_orders                                       38.0
# ...

# %% [markdown]
# dado el menos tiempo buscamos el registro con el menor tiempo posible, asi obtenemos el tipo de comida con el menor tiempo posible siendo chocolate

# %% [markdown]
# pregunta 1

# %%
datos6=pd.read_csv('historical_data.csv')
datos6=datos6.dropna(axis=0)
datos7=datos.groupby('store_id')
datos8=datos6

# %% [markdown]
# Hacemos un grupo para las tiendas  y limpiamos los datos eliminando los datos null

# %%
datos8['sum'] = datos7['subtotal'].transform('sum')

# %% [markdown]
# creamos una fila donde contamos el total de ventas de cada tienda

# %%
datos8
# Out:
#         market_id           created_at actual_delivery_time  store_id  \
# 0             1.0  2015-02-06 22:24:17  2015-02-06 23:27:16      1845
# 1             2.0  2015-02-10 21:49:25  2015-02-10 22:56:29      5477
# 8             2.0  2015-02-16 00:11:35  2015-02-16 00:38:01      5477
# 14            1.0  2015-02-12 03:36:46  2015-02-12 04:14:39      2841
# 15            1.0  2015-01-27 02:12:36  2015-01-27 03:02:24      2841
# ...           ...                  ...                  ...       ...
# 197423        1.0  2015-02-17 00:19:41  2015-02-17 01:24:48      2956
# 197424        1.0  2015-02-13 00:01:59  2015-02-13 00:58:22      2956
# 197425        1.0  2015-01-24 04:46:08  2015-01-24 05:36:16      2956
# 197426        1.0  2015-02-01 18:18:15  2015-02-01 19:23:22      3630
# 197427        1.0  2015-02-08 19:24:33  2015-02-08 20:01:41      3630
#
#        store_primary_category  order_protocol  total_items  subtotal  \
# ...

# %%
datos8.max()
# Out:
# market_id                                                       6.0
# created_at                                      2015-02-18 06:00:44
# actual_delivery_time                            2015-02-19 22:45:31
# store_id                                                       6987
# store_primary_category                                   vietnamese
# order_protocol                                                  7.0
# total_items                                                     411
# subtotal                                                      26800
# num_distinct_items                                               20
# min_item_price                                                14700
# max_item_price                                                14700
# total_onshift_dashers                                         171.0
# total_busy_dashers                                            154.0
# total_outstanding_orders                                      285.0
# ...

# %% [markdown]
# vemos el monto de mayor ventas de todas

# %%
datos9=datos8[['store_id','sum']]

# %% [markdown]
# separamos las tiendas y cuantos vendieron en total

# %%
datos9
# Out:
#         store_id     sum
# 0           1845    3441
# 1           5477   48607
# 8           5477   48607
# 14          2841   17145
# 15          2841   17145
# ...          ...     ...
# 197423      2956  121765
# 197424      2956  121765
# 197425      2956  121765
# 197426      3630    3780
# 197427      3630    3780
#
# [175777 rows x 2 columns]

# %%
datos10=datos9.set_index('sum', inplace=True)

# %%
datos9
# Out:
#         store_id
# sum
# 3441        1845
# 48607       5477
# 48607       5477
# 17145       2841
# 17145       2841
# ...          ...
# 121765      2956
# 121765      2956
# 121765      2956
# 3780        3630
# 3780        3630
#
# [175777 rows x 1 columns]

# %% [markdown]
# ponemos como indice el el total de ventas

# %%
datos9=datos9.drop_duplicates()
datos9.loc[2636241]
# Out:
# store_id    6074
# Name: 2636241, dtype: int64

# %% [markdown]
# eliminamos los duplicados de las tiendas y asi solo tenemos una tienda con un total de ventas y depsues buscamos con la funcion loc la tienda con la mayor ventas de todas que fue la tienda id 6074

# %% [markdown]
# Pregunta 5

# %%
datos6=pd.read_csv('historical_data.csv')
datos6=datos6.dropna(axis=0)
datos11=datos.groupby('market_id')
datos12=datos6

# %% [markdown]
# agrupamos todas las tiendas

# %%
datos12['sum'] = datos11['market_id'].transform('count')

# %% [markdown]
# contamos cuantos pedidos tienen por region

# %%
datos12.min()
# Out:
# market_id                                                       1.0
# created_at                                      2015-01-21 15:22:03
# actual_delivery_time                            2015-01-21 16:16:34
# store_id                                                          1
# store_primary_category                                       afghan
# order_protocol                                                  1.0
# total_items                                                       1
# subtotal                                                          0
# num_distinct_items                                                1
# min_item_price                                                  -86
# max_item_price                                                    0
# total_onshift_dashers                                          -4.0
# total_busy_dashers                                             -5.0
# total_outstanding_orders                                       -6.0
# ...

# %% [markdown]
# vemos el valor minimo del resultado de la cantidad de pedidos en cada region

# %%
datos13=datos12[['market_id','sum']]

# %% [markdown]
# separamos los datos market_id y el contador

# %%
datos14=datos13.set_index('sum', inplace=True)
datos13=datos13.drop_duplicates()
datos13
# Out:
#          market_id
# sum
# 38037.0        1.0
# 55058.0        2.0
# 23297.0        3.0
# 47599.0        4.0
# 18000.0        5.0
# 14450.0        6.0

# %% [markdown]
# ponemos como indices los contadores y despues eliminamos los duplicados

# %% [markdown]
# obtenemos la region con menos pedidos de todas siendo la region 6

# %%
datos12['times']= pd.to_datetime(datos12['created_at']).dt.hour

# %% [markdown]
# creamos una nueva columna que seran la hora del dia del pedido

# %%
datos12
# Out:
#         market_id           created_at actual_delivery_time  store_id  \
# 0             1.0  2015-02-06 22:24:17  2015-02-06 23:27:16      1845
# 1             2.0  2015-02-10 21:49:25  2015-02-10 22:56:29      5477
# 8             2.0  2015-02-16 00:11:35  2015-02-16 00:38:01      5477
# 14            1.0  2015-02-12 03:36:46  2015-02-12 04:14:39      2841
# 15            1.0  2015-01-27 02:12:36  2015-01-27 03:02:24      2841
# ...           ...                  ...                  ...       ...
# 197423        1.0  2015-02-17 00:19:41  2015-02-17 01:24:48      2956
# 197424        1.0  2015-02-13 00:01:59  2015-02-13 00:58:22      2956
# 197425        1.0  2015-01-24 04:46:08  2015-01-24 05:36:16      2956
# 197426        1.0  2015-02-01 18:18:15  2015-02-01 19:23:22      3630
# 197427        1.0  2015-02-08 19:24:33  2015-02-08 20:01:41      3630
#
#        store_primary_category  order_protocol  total_items  subtotal  \
# ...

# %%
datos13=datos12[(datos12['times']<22) & (datos12['times']>16) & (datos12['market_id']==6)]

# %% [markdown]
# filtramos los datos de la region con menos pedidos entre las horas de 17h-22h siendo (5pm a 10pm)

# %%
datos13
# Out:
#         market_id           created_at actual_delivery_time  store_id  \
# 525           6.0  2015-02-04 19:49:41  2015-02-04 20:29:05      2716
# 1474          6.0  2015-02-13 18:24:10  2015-02-13 18:51:39       517
# 2298          6.0  2015-01-25 19:15:34  2015-01-25 20:01:30      5711
# 4909          6.0  2015-02-16 21:55:14  2015-02-16 22:48:52      4221
# 6075          6.0  2015-01-30 19:24:50  2015-01-30 20:48:58      2722
# ...           ...                  ...                  ...       ...
# 194463        6.0  2015-02-14 20:32:10  2015-02-14 21:04:17      1409
# 194944        6.0  2015-02-04 19:42:32  2015-02-04 20:33:28      4756
# 195694        6.0  2015-02-02 18:33:25  2015-02-02 19:28:50      5201
# 195829        6.0  2015-01-28 19:21:29  2015-01-28 20:08:24      4862
# 197067        6.0  2015-01-23 20:37:37  2015-01-23 21:15:08      1409
#
#        store_primary_category  order_protocol  total_items  subtotal  \
# ...

# %%
datos14=datos13.groupby('times')

# %% [markdown]
# hacemos una agrupacion de los tiempos

# %%
datos13['count']=datos14['times'].transform('count')
# Out:
# <ipython-input-39-026ba1722e1a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos13['count']=datos14['times'].transform('count')

# %% [markdown]
# contamos la cantidad de los tiempos de los pedidos

# %%
datos15=datos13[['times','count']]

# %%
datos16=datos15.set_index('count', inplace=True)

# %% [markdown]
# separamos los times y contadores

# %%
datos15
# Out:
#        times
# count
# 43        19
# 12        18
# 43        19
# 33        21
# 43        19
# ...      ...
# 41        20
# 43        19
# 12        18
# 43        19
# 41        20
#
# [144 rows x 1 columns]

# %%
datos15=datos15.drop_duplicates()
datos15
# Out:
#        times
# count
# 43        19
# 12        18
# 33        21
# 41        20
# 15        17

# %% [markdown]
# ponemos como indices los count y eliminamos los datos duplicados asi obtenemos de 17-22 la hora  donde se realizan menor cantidad de pedidos, y seria la mejor hora para ordenar siendo 18h con la menor cantidad de pedidos
